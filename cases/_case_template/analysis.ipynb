# %% [markdown]
# # Practical UPL Case Analysis
#
# Read the sibling `README.md` case contract before analysis. Record the data-state reference, query maintained Postgres read-only through `src.research.read_sql`, run proportionate checks, and keep the final path to every reported result understandable.

# %% [markdown]
# ## TL;DR
#
# Write this last. State the answer and the strongest supporting evidence without exceeding the case design.

# %% [markdown]
# ## Context & Methods
#
# Restate the bounded question, scope, definitions, assumptions, and least complex defensible method from the case contract.

# %% [markdown]
# ## Data & Checks
#
# Record the database/run and migration state, tables and fields, query parameters, coverage, and proportionate checks. Query maintained Postgres read-only through `src.research.read_sql`.

# %% [markdown]
# ## Results
#
# Keep the final reproducible path to every reported table, estimate, or figure understandable. Bound exploratory output and label deliberate artifacts.

# %% [markdown]
# ## Takeaways & Limitations
#
# Separate supported findings, football interpretation, limitations, non-claims, and follow-up questions before carrying the answer into `report.md`.
